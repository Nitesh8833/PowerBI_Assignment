# %%
Objective: Power BI Desktop, Cloud Service and End to End Workflow. 
Topic: Parameters. 
Exercise: Create a DAX measure such that data should be showed to the users 
only if something is searched on the slicer.
Expected Output if nothing is searched on slicer.
Expected output if Suburb store setting is searc

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)
