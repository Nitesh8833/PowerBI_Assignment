# %%
Assignment - 13 Tooltips
Objective – Power BI Desktop, Cloud Service and End to EndWorkflow 
Use Case – Working with Tooltips 
Source – Authors 
Analytics – Create Tooltips
Report/Dashboard – Bookmark as action
• Open the Power BI report file in the above folder. It shows the 100 
bestselling books since 1998:
• Create a tooltip page to show the volume of sales for each title:
• Assign this page to be the tooltip for the original visual:
What you might see if you hover over Bill Bryson, for example.
• If you still have time, and want a challenge, create and display a 
measure to show the name of the author in your tooltip:
The report page tooltip now shows the name of the author chosen in 
the title.
• Save & Publish as Authors Info
Result – Tooltip Enable Report

# %% [markdown]
# ![1.png](attachment:1.png)
