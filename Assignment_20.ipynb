# %% [markdown]
# Objective: Power BI Desktop, Cloud Service and End to End Workflow.
# Topic: Charts.
# Exercise: Create date and normal slicers on one page to affect visuals on other
# pages.
# • On the empty Choices page, add the following slicers:
# • Add in a slicer allowing you to choose the event date:
# • Using the Sync slicers pane, configure your report so that the slicers only
# appear on the first page, but apply to the other pages

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)
