# %% [markdown]
# It contains a table giving how many times the author would need to
# pop out for a comfort break during each film's screening:
# From this table you should be able to make a reasonable guess at the
# author's age ...
# • In the Films table create a calculated column called NumberBreaks
# which shows for each film the number of breaks needed.
# When you've finished, you should be able to create the following
# matrix:
# • try creating a second calculated column to do the same
# thing, but this time using the method you didn't use the
# first time.

# %% [markdown]
# ![1.png](attachment:1.png)
