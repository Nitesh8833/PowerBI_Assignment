# %%
Objective – Power BI Desktop, Cloud Service and End to EndWorkflow 
Use Case – Working with Bookmark as action 
Source – Zoo 
Analytics – Create Bookmark
Report/Dashboard – Bookmark as action
• Try to make a report which has a page for each kind of Image. When 
you click the image of that creature you will see all the animals of the 
same type:
• To get you started look in the above folder to find the three images 
used. Note the names of the images. Create a page with a table for 
each:
• When the pages are all created, hide them so that the only way user 
can reach the page is by clicking the relevant image on the first page.
Don't try and hide all the pages. One must remain visible - otherwise how will 
they get to the hidden pages!
• To create the bookmarks make sure you have the bookmark feature 
turned on in the View tab:
• Now choose the first page to create as a bookmark, and choose Add in 
the Bookmark Pane:
Leave all the other options ticked for the time being. Name the 
bookmark after the page.
• Clicking on the turtle should now take you through to the water page 
we created earlier
• Adding a back arrow which returns you to the first page of the report. 
Use the type Back instead of Bookmark when creating the Link.
• Save & Publish as Zoo
Result – Bookmark with Image actio

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# ![4.png](attachment:4.png)
